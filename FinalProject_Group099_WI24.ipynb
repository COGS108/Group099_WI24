# %% [markdown]
# # Does the use of public transport in California decrease the number and/or severity of car crashes?
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Names
#
# - Nicole Kim
# - Rikako Ono
# - Geena Limfat
# - MyungJoo Kim
# - Elizaveta Beltyukova

# %% [markdown]
# # Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.
#
# Our research question seeks to identify whether or not higher usages of public transportation affects the number of car accidents in that area. Additionally, whether  higher use of public transportation will affect the severity of these car crashes.

# %% [markdown]
# # Research Question

# %% [markdown]
# Does higher usage of public transportation in a county affect the number of car accidents in that county?
#
# Additionally, does higher use of public transportation lessen the severity of the car accident?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Over the years, advancements in car safety, including structural design improvements and technological developments, have enhanced vehicle safety.
# Despite these progressions, the frequency of car accidents has increased significantly in recent years.
# In the United States alone, there were 6,102,936 police-reported vehicle accidents in 2021<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2).
# Various factors contribute to car crashes in the US, such as distracted driving, speeding, drunk driving, reckless driving, and tailgating.
# Notably, more than a third (36%) of all fatal crashes involve alcohol<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2).
#
# These behaviors collectively contribute to the high rate of car accidents in the US, underlining the importance of addressing these issues through awareness campaigns, preventive measures, and effective policies to enhance road safety.
#
# Public transportation serves as a vital component of urban areas by offering consistent transportation services through modes like buses, streetcars, light rail, ferries, and subways.
# This mode of transportation is essential for diverse groups such as older adults, individuals with disabilities, and commuters, particularly in major cities where public transit is prevalent.
# Public transportation not only provides a means of travel but also contributes to health and equity in various ways.
# Research indicates that public transportation can reduce traffic accidents and air pollution while increasing physical activity and improving access to essential services like medical care, healthy food, employment opportunities, and social connections.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3).
# Despite these benefits, it remains unexplored whether the utilization of public transportation correlates with the severity of car crashes in an area.
#
# To investigate the relationship between public transport usage and the number and severity of car crashes in an area, one could explore how increased public transportation utilization might lead to reduced traffic congestion and fewer private vehicles on the road.
# However, it’s also possible that less traffic congestion could encourage drivers to travel at higher speeds, thus being more likely to cause a more severe/fatal accident in the area.
# Another factor to consider is that with increased public transport use, there could be more pedestrians, and therefore potentially more car-caused pedestrian injuries or deaths.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) [Evaluating Public Transportation Health Benefits. (n.d.).](https://www.vtpi.org/tran_health.pdf)
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) [Moore, T. (2024, January 16). Fatal car crash statistics 2024. USA Today.](https://www.usatoday.com/money/blueprint/auto-insurance/fatal-car-crash-statistics/#:~:text=There%20are%20nearly%2043%2C000%20fatal,accidents%20in%20the%20United%20States.&text=Of%20those%2C%2039%2C508%20were%20fatal)
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) [Top 25 causes of car accidents: Exploring the major factors. GJEL Accident Attorneys. (2023, November 24).](https://www.gjel.com/car-accident-lawyers/top-causes-car-accidents )

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Alternate Hypothesis: We hypothesize that higher use of public transportation lessens the number of accidents due to several factors. One of the factors being that public transportation involves professional drivers who go through rigorous training to operate the mode of transportation that they are in charge of and may adhere more strictly to traffic regulations and safety protocols which can reduce the likelihood of accidents. Therefore, they will be better experienced and equipped to handle situations that may cause accidents. Additionally, a higher usage of public transportation will result in fewer vehicles on the road which can reduce congestion and lower the probability of accidents. Thus, we hypothesize that a higher utilization of public transportation could contribute to a safer transportation environment and reduce the number of accidents on the road. In addition to this, we believe that higher use of public transportation will also lessen the severity of car accidents that occur. A higher use of public transportation indicates that there will be fewer vehicles on the road which can potentially reduce the number of reckless drivers on the road as well. Fewer reckless drivers on the road can lessen the severity of accidents. Since there are also less cars on the road, there would be less cars to crash into each other and create a 'domino effect' and involve other vehicles, thus involving less people and potentially lessening the overall severity of the entire crash. Additionally, public transportation drivers are better equipped to handle accidents as they have more training so they can better react to the situation and potentially lesssen the severity of the crash.
#
# Null Hypothesis: The use of public transportation does not affect the number of car crashes. It also does not affect the severity of the accident.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1
#   - Dataset Name: US Accidents (2016 - 2023)
#   - Link to the dataset: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents?select=US_Accidents_March23.csv
#   - Number of observations: 7,728,394
#   - Number of variables: 46
# - Dataset #2
#   - Dataset Name: Highest Public Transit Usage Cities in California
#   - Link to the dataset: https://www.homearea.com/rankings/place-in-ca/percent_using_public_transportation/#:~:text=The%20California%20percent%20using%20public,year%20saw%20several%20big%20changes
#   - Number of observations: 62
#   - Number of variables: 3
# - Dataset #3
#   - Dataset Name: City and Town Population Totals: 2010-2019
#   - Link to the dataset: https://www.census.gov/data/tables/time-series/demo/popest/2010s-total-cities-and-towns.html
#   - Number of observations: 490
#   - Number of variables: 13
#
# The first dataset refers to the US accident, encompassing 7,728,394 observations recorded between 2016 and 2023.
# The main features in this dataset include  the name of City, start time, description of the accident, and severity.
# The second dataset focuses  on public transportation usage in California, specifically in 62 cities in CA. This dataset comprises exactly 62 observations, each corresponding to a different city.
# The third dataset is the population of various California cities, which we will use to find per capita accident rates to ensure Dataset #1 and Dataset #2 have the same units of measurement.
#
# We decided to merge a subset of the first dataset comprised of accident data from California in 2017 with the second dataset, which details public transportation usage across 62 cities in California, to measure the correlation between the US car accident rate and public transportation usage in California during 2017. This lets us directly assess how public transportation affects car accident rates within the cities in California.
# This combined dataset allows a comprehensive analysis of the relationship between public transportation use, and various factors influencing car accidents in California.

# %% [markdown]
# ## Data Cleaning
#
# ### Dataset #1
#
# This dataset is somewhat clean. The dataset is consistent and uniform throughout.
# In terms of pre-processing, we noticed that there was a small issue with completeness, as there was some missing data.
# As the dataset's description states, “There is missing data for certain days, which could be due to network connectivity issues during data collection.” We will handle this issue by removing these missing inputs. Additionally, we will attempt to make the file smaller so that it can be cleaned and uploaded to GitHub.
#
# For the correct values that do remain, we are still confident that they are accurate and reliable. In the description, it states, “The data was collected from APIs broadcast traffic data captured by various entities, including the US and state departments of transportation, law enforcement agencies, traffic cameras, and traffic sensors within the road networks.” Because APIs have low latency, real-time data processing, and quick response times, we can conclude that the data is precise. We can also conclude from this excerpt that the sources are credible and trustworthy. We have also confirmed that the dataset included at least a year’s worth of data to observe trends for appropriate time frames. We also checked that the source was reliable.
#
# To make our data usable, we first converted the ‘Start_Time’ column into a datetime object, so that we can filter the crash data by year (2017). Within the to_datetime function, we specified errors = ‘coerce’ to better handle improper formatted or mixed date strings in the dataframe. Then, we filtered the state to just be California, and the year to just be 2017 (using dt.year). Then, we selected the columns ‘Start_Time’, ‘Severity’, ‘City’, and ‘Description’, and sorted the dataframe by Start_Time, while also resetting the index.
#
#
#
# ### Dataset #2
#
# This dataset is very clean. This is mainly because we created our own data set. Thus, we had full control over the quality of the data set and over what variables, observations, and units of measurement were included. In terms of pre-processing, we made sure all the data was consistent and complete. We cleaned the data and checked that it included at least a year’s worth of data to observe trends for appropriate time frames. We checked that it was consistent with our other data set.
#
# We ensured the credibility of the data by making sure it was taken from a reputable source like the U.S. Census Bureau American Community Survey. Unfortunately, the data may have small holes in precision, as survey participation is often voluntary. However, the source states that certain cities “were ranked the previous year but did not have sufficient data or population for the most recent rankings.” From this, we can conclude that the source has only published results that have solid data to support them, thus making the research conducted accurate.
#
# To get the data into a usable format we had to take research and statistics from various websites related to our study.
# We then had to transform the file type twice. First, we inputted data into an Excel spreadsheet for ease of viewing and editing.
# Second, we converted the file into a CSV to be read by pandas.

# %% [markdown]
# ### Set up

# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import statsmodels.api as sm

# %% [markdown]
# ## Dataset #1 - US Accidents (2016 - 2023)

# %% [markdown]
# Because the original dataset was too large to be uploaded on GitHub, we cleaned the data locally with the following code:
#
#
# ```python
# df = pd.read_csv('US_Accidents_March23.csv')
#
# # create a subset of the dataset with relevant year 2017, which we will be using for the rest of the project
# df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')
#
# accidents_df = df[df['State'] == 'CA'][df['Start_Time'].dt.year == 2017]
# accidents_df = accidents_df.get(['Start_Time', 'Severity', 'City', 'Description']).sort_values(by='Start_Time').reset_index(drop=True)
#
# accidents_df.to_csv(r"~\AccidentData.csv", index=False)
# ```

# %%
accident_df = pd.read_csv('AccidentData.csv')

# normalize severity to be on a scale of 0-1 instead of 1-4 to make comparing easier later on
accident_df['Severity'] = accident_df['Severity']/4

accident_df.head()
# Out:
#             Start_Time  Severity      City  \
# 0  2017-01-01 00:03:31      0.75   Norwalk
# 1  2017-01-01 00:09:26      0.75   Lynwood
# 2  2017-01-01 00:09:52      0.75  Hesperia
# 3  2017-01-01 00:10:14      0.50  Pasadena
# 4  2017-01-01 00:11:14      0.75    Colton
#
#                                          Description
# 0  Accident on I-5 Northbound at Exits 120 120A B...
# 1  Accident on I-710 Southbound at Exits 12 12A 1...
# 2  Accident on I-15 Northbound at Exit 138 Oak Hi...
# 3       Accident on CA-110 Southbound at Glenarm St.
# 4       Accident on I-10 Eastbound at Exit 72 I-215.

# %% [markdown]
# ## Dataset #2 - Highest Public Transit Usage Cities in California

# %%
City = ['San Francisco', 'Oakland', 'Berkeley', 'Daly City', 'Alameda', 'San Leandro', 'Richmond', 'Pleasanton', 'San Mateo', 'Concord', 'San Ramon', 'Hayward', 'Los Angeles', 'Mountain View', 'Fremont', 'Antioch', 'Sunnyvale', 'Pittsburg', 'East Los Angeles', 'Redwood City', 'Vallejo', 'Pasadena', 'Long Beach', 'El Cajon', 'San Jose', 'Santa Clara', 'Santa Ana', 'Inglewood', 'South Gate', 'San Diego', 'Downey', 'Sacramento', 'Chula Vista', 'Santa Clarita', 'Glendale', 'Anaheim', 'Escondido', 'Riverside', 'Santa Rosa', 'Oceanside', 'Santa Barbara', 'Elk Grove', 'Palmdale', 'San Bernardino', 'Fullerton', 'Fresno', 'Moreno Valley', 'Pomona', 'Huntington Beach', 'Santa Maria', 'Lancaster', 'Ontario', 'Garden Grove', 'Corona', 'Bakersfield', 'Stockton', 'Rancho Cucamonga', 'Lakewood', 'San Buenaventura (Ventura)', 'Irvine', 'Visalia', 'Napa']
Percent_Used = [0.347, 0.227, 0.221, 0.207, 0.185, 0.149, 0.121, 0.105, 0.103, 0.099, 0.098, 0.098, 0.089, 0.088, 0.081, 0.079, 0.076, 0.071, 0.066, 0.066, 0.061, 0.055, 0.055, 0.053, 0.05, 0.049, 0.048, 0.047, 0.046, 0.04, 0.038, 0.038, 0.036, 0.034, 0.033, 0.031, 0.03, 0.03, 0.026, 0.023, 0.023, 0.021, 0.021, 0.021, 0.021, 0.02, 0.019, 0.018, 0.018, 0.018, 0.016, 0.015, 0.014, 0.012, 0.011, 0.011, 0.011, 0.008, 0.008, 0.008, 0.006, 0.005]

transit_df = pd.DataFrame({'City':City, 'Percent Using Transit':Percent_Used})

transit_df
# Out:
#                           City  Percent Using Transit
# 0                San Francisco                  0.347
# 1                      Oakland                  0.227
# 2                     Berkeley                  0.221
# 3                    Daly City                  0.207
# 4                      Alameda                  0.185
# ..                         ...                    ...
# 57                    Lakewood                  0.008
# 58  San Buenaventura (Ventura)                  0.008
# 59                      Irvine                  0.008
# 60                     Visalia                  0.006
# 61                        Napa                  0.005
#
# [62 rows x 2 columns]

# %%
# To better compare the datasets, we will merge them by city name.

accident_df_new = accident_df.groupby('City').agg(avg_severity=('Severity', "mean"), num_accidents=('Description', np.count_nonzero)).reset_index()
accidents_vs_transit = pd.merge(accident_df_new, transit_df, on='City')
accidents_vs_transit.head(10)
# Out:
#           City  avg_severity  num_accidents  Percent Using Transit
# 0      Alameda      0.500000              6                  0.185
# 1      Anaheim      0.546612           2022                  0.031
# 2      Antioch      0.514423            208                  0.079
# 3  Bakersfield      0.534253            562                  0.011
# 4     Berkeley      0.694248            565                  0.221
# 5  Chula Vista      0.662577            326                  0.036
# 6      Concord      0.540720            528                  0.099
# 7       Corona      0.576827           1793                  0.012
# 8    Daly City      0.640288            278                  0.207
# 9       Downey      0.696450            845                  0.038

# %% [markdown]
# ## Dataset #3 - City and Town Population Totals: 2010-2019

# %%
population_df = pd.read_excel('SUB-IP-EST2019-ANNRES-06.xlsx')

population_df.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                          Adelanto city, California
# 4                      Agoura Hills city, California
#
#             Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0                  NaN             NaN                                 NaN
# 1  2010-04-01 00:00:00             NaN  Population Estimate (as of July 1)
# 2               Census  Estimates Base                                2010
# 3                31765           31760                               31661
# 4                20330           20336                               20338
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
# The code does not have proper column markers, and has excess information. We will fix that with the following:

# Fix column values
col_values = population_df.iloc[2]
col_values.iloc[0] = population_df.iloc[1].iloc[0]
population_df.columns = col_values

# Simplify rows and columns
population_df = population_df[3:]
population_df = population_df.reset_index(drop=True).get(['Geographic Area', 2017.0]).rename(columns={'Geographic Area': 'City', 2017.0:'Population in 2017'})
population_df['City'] = population_df['City'].str.title().str.replace(', California', '').str.replace(' City', '')
population_df.dropna(inplace=True)

    
population_df.head()
# Out:
# 2          City  Population in 2017
# 0      Adelanto             33952.0
# 1  Agoura Hills             20572.0
# 2       Alameda             79037.0
# 3        Albany             20076.0
# 4      Alhambra             84878.0

# %%
#We will merge this into the dataset 'accidents_vs_transit' to get the per-capita accident rate of each city.

clean_df = pd.merge(accidents_vs_transit, population_df, on='City')

clean_df = clean_df.assign(accident_rate = clean_df['num_accidents']/clean_df['Population in 2017'])

clean_df = clean_df.get(['City', 'num_accidents', 'Population in 2017', 'accident_rate', 'avg_severity', 'Percent Using Transit'])

# Look at some values in our cleaned dataframe
clean_df.head(10)
# Out:
#           City  num_accidents  Population in 2017  accident_rate  \
# 0      Alameda              6             79037.0       0.000076
# 1      Anaheim           2022            350476.0       0.005769
# 2      Antioch            208            111494.0       0.001866
# 3  Bakersfield            562            377940.0       0.001487
# 4     Berkeley            565            122164.0       0.004625
# 5  Chula Vista            326            269046.0       0.001212
# 6      Concord            528            129592.0       0.004074
# 7       Corona           1793            167310.0       0.010717
# 8       Downey            845            112426.0       0.007516
# 9     El Cajon            371            103468.0       0.003586
#
#    avg_severity  Percent Using Transit
# 0      0.500000                  0.185
# 1      0.546612                  0.031
# 2      0.514423                  0.079
# 3      0.534253                  0.011
# 4      0.694248                  0.221
# ...

# %% [markdown]
# Through cleaning the data, it can be observed that the length of our dataset shortened to 58 observations. This is due to some of the values not being in the other datasets.

# %% [markdown]
# # Data Analysis & Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# We start by examining the distribution of the variables in question: car crashes that occur in California, alongside transit use rates and population, to visualize if there are any similarities.

# %%
sub_col_crash_by_city = ['City', 'num_accidents']
sub_crash_by_city = clean_df[sub_col_crash_by_city]

sns.barplot(data=sub_crash_by_city, x='num_accidents', y='City', hue='City', palette="Set2")
sns.color_palette("Set2")
plt.xlabel('Number of Crashes')
plt.yticks(fontsize = '5')
plt.ylabel('City')
plt.title('Total Number of Car Crashes in California Cities (2017)')

plt.show()

# %% [markdown]
# We chose to make this next bar graph because we wanted a clean visual representation of the next dataset. We wished to easily reference which cities had the lowest and highest usage of public transportation in CA.

# %%
# create a bar plot representing the public transporation use rates in California cities
sns.barplot(data=clean_df, x='Percent Using Transit', y='City', hue='City', palette="mako")
plt.xlabel('Public Transportation Use Rates')
plt.yticks(fontsize = '5')
plt.ylabel('City')
plt.title('Public Transportation Use Rates by California City (2017)')

plt.show()

# %% [markdown]
# We expect that population *may* be a confounding variable. To see if there might be similar trends, we will plot the population of each California city in our dataset in a bar plot.

# %%
# create a barplot representing the population of each California City
sns.barplot(data=clean_df, x='Population in 2017', y='City', hue='City', palette="magma")
plt.xlabel('Population')
plt.yticks(fontsize = '5')
plt.ylabel('City')
plt.title('Population of California Cities (2017)')

plt.show()

# %% [markdown]
# There seem to be similarities in the plots, such as where peaks are located. In the next sections (EDA), we will explore how each of these variables (Transit Use Rates and Population) affect car crash rates in Californian cities.

# %% [markdown]
# ### __Part 1: Exploring relationships with "Percent Using Transit"__

# %% [markdown]
# We chose to use scatterplots here because we wanted to see if we could identify a relationship in the points plotted between Accident Rate vs. Percent Using Transit and  Accident Severity vs. Percent Using Transit.

# %%
# Create a figure and axes objects for subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot the first scatter plot (accident rate vs. percent using transit)
clean_df.plot.scatter(x='Percent Using Transit', y='accident_rate', ax=axes[0])
axes[0].set_title('Accident Rate vs. Percent Using Transit')
axes[0].set_xlabel('Percent Using Transit')
axes[0].set_ylabel('Accident Rate')
axes[0].grid(True)

# Plot the second scatter plot (average severity vs. percent using transit)
clean_df.plot.scatter(x='Percent Using Transit', y='avg_severity', ax=axes[1])
axes[1].set_title('Average Severity vs. Percent Using Transit')
axes[1].set_xlabel('Percent Using Transit')
axes[1].set_ylabel('Average Severity')
axes[1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# <ins>Scatterplot of Accident Rates and Percent Using Transit (by city in California):</ins>
#
# 1. The two variables seem to have an overall moderate, positive, linear distribution. There seems to be one data cluster closer to the origin, and some outliers for both variables (relatively extreme accident rates and public transportation usage rates).
# 2. The most prominent outlier belongs to the city of San Francisco. The very low accident rate outlier belongs to Alameda. There are two more outliers in between those points, Oakland and Berkeley. It’s interesting to note that all of those points are cities in the San Francisco Bay Area, which is an area of moderate to high transport use due to BART and CalTrain systems. Also, locals in San Francisco tend to use the bus or trolley to get around. There are also two outliers that are prominent due to their high accident rates: Corona and Sacramento. Those outliers might be explained by the dense population and busy streets. Overall, there are obvious outliers on the graph, but they make logical sense when taking into consideration each city.
# 3. We chose to study “Accident Rates” and “Percent Using Transit'' because we wanted to see if our hypothesis was supported: The higher use of public transportation lessens the number of accidents. Based on the graph and analysis of its distributions, it seems like there is a moderate positive linear relationship between “Accident Rates” and “Percent Using Transit”  in cities of California.
#
# <ins>Scatterplot of Accident Severity and Percent Using Transit (by city in California):</ins>
#
# 1. We can observe that there are two data clusters (high severity and low severity). We can also observe that most of the points are close to the origin (small in x-value). We can say that the graph looks similar to a positive linear relationship, but the strength is too weak. It almost feels like it needs to have two lines drawn instead of a singular one. Thus, the distribution of the points is not clear enough to conclude that there is a positive relationship between “Accident Severity” and “Percent Using Transit.”
# 2. Yes, there are outliers in the graph. Similar to the previous graph, the high “Percent Using Transit” outlier belongs to San Francisco. The very low “Accident Severity” outlier belongs to Alameda. The reasoning for the most extreme outlier can be supported. San Francisco is an outlier due to its higher usage of public transportation such as the metro, cable cars, Muni buses, and more. Because it is a popular tourist location and the city is notorious for it being a hassle to park, it makes sense that many people would rather utilize transit than drive or rent personal vehicles. Upon further research, we decided that the Alameda outlier could be justified with project “Vision Zero.” According to the official government website, “Vision Zero is an international movement that aims to reduce traffic deaths and life-changing injuries to zero, while increasing safe, healthy, equitable mobility for all”<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4).
# 3. We chose to study “Accident Severity” and “Percent Using Transit” because we wanted to see if our hypothesis was supported: Accidents are less severe when there is a higher percentage of people using transit. Based on the graph and analysis of its distributions, we cannot conclude that there is a correlation between the variables: “Accident Severity” and “Percent Using Transit.” Thus, we see that our null hypothesis is correct instead.
#
#
#  <a name="cite_note-4"></a>  [^](#cite_ref-3) [Vision Zero](https://www.alamedaca.gov/Departments/Planning-Building-and-Transportation/Transportation/Vision-Zero)

# %% [markdown]
# Looking at our two scatterplots, we noticed that there was no linear relationship found between Average Severity of car accidents and Percent Using Transit in a city. Therefore, we decided to proceed to explore the variables with a more promising result: Accident Rate vs. Percent Using Transit.

# %% [markdown]
# ### __Part 2.1: Exploring relationships with "Accident Rate"__
#
# <ins>Linear Regression of Accident Rate and Percent Using Transit:</ins>
# 1. In the graph, we observed that most of the blue points are very far away from the blue best-fit line.
# 2. They are located at approximately (-0.95, 0.0105), (-0.85, 0.012), (-0.54, 0.000), and (-0.35, 0.002).
# 3. We chose to study "Accident Rate" and "Percent Using Transit" applied with a log10 transformation.
# We applied this arithmetic to shift the values away from being centered near zero when put on the log scale.
#
# <ins>Linear Regression of Accident Rate and Population in 2017:</ins>
# 1. In the graph, we observed that the orange points are closer to the orange best-fit line when compared to the blue line and its points.
# 2. They are located at approximately (-0.81, 0.011) and (-0.35, 0.0081).
# 3. We chose to study "Population in 2017" divided by 10^8 to fit all the points in the graph.
# We chose to study "Percent Using Transit" applied with log10 to shift the values away from being centered near zero when put on the log scale.

# %%
# create a subset of clean_df for column of interest for linear regression model
sub_col_acc_transit = ['accident_rate','Percent Using Transit']
sub_accident_rate = clean_df[sub_col_acc_transit]

# Apply a log-10 transformation for less skewed dataset

sub_accident_rate['transit_log10'] = np.log10(sub_accident_rate['Percent Using Transit']+0.1)
sub_accident_rate.head()
# Out:
#    accident_rate  Percent Using Transit  transit_log10
# 0       0.000076                  0.185      -0.545155
# 1       0.005769                  0.031      -0.882729
# 2       0.001866                  0.079      -0.747147
# 3       0.001487                  0.011      -0.954677
# 4       0.004625                  0.221      -0.493495

# %%
sub_col_2 = ['accident_rate','Percent Using Transit','Population in 2017']
sub_accident_rate_2 = clean_df[sub_col_2]

# Apply a log-10 transformation for less skewed dataset

sub_accident_rate_2['transit_log10'] = np.log10(sub_accident_rate_2['Percent Using Transit']+0.1)

# filter out the outliers from 'Population in 2017'
x = 2
mean = sub_accident_rate_2['Population in 2017'].mean()
std = sub_accident_rate_2['Population in 2017'].std()
filtered_pop  = sub_accident_rate_2[(sub_accident_rate_2['Population in 2017'] > (mean - x * std)) & (sub_accident_rate_2['Population in 2017']< (mean + x * std))]
filtered_pop

# Divide 'Population in 2017'by 1e8 to make it comparable in range of accident rate 
filtered_pop['pop_comp'] = filtered_pop['Population in 2017']/1e8
filtered_pop.head()
# Out:
#    accident_rate  Percent Using Transit  Population in 2017  transit_log10  \
# 0       0.000076                  0.185             79037.0      -0.545155
# 1       0.005769                  0.031            350476.0      -0.882729
# 2       0.001866                  0.079            111494.0      -0.747147
# 3       0.001487                  0.011            377940.0      -0.954677
# 4       0.004625                  0.221            122164.0      -0.493495
#
#    pop_comp
# 0  0.000790
# 1  0.003505
# 2  0.001115
# 3  0.003779
# 4  0.001222

# %% [markdown]
# After removing outliers, we used a Linear Regression as well as an OLS model because we wanted to see if there was a significant relationship between (1) Accident Rate vs. Transit Usage Rate, (2) Accident Rate vs. Population in 2017 and (3) Accident Rate and Percent Using Transit + Population in 2017.

# %%
fig, ax = plt.subplots(figsize=(14, 8))


sns.regplot(x='transit_log10', y='accident_rate', data=filtered_pop, fit_reg=True, ax=ax, label='Accident Rate')
sns.regplot(x='transit_log10', y='pop_comp', data=filtered_pop, fit_reg=True, ax=ax, label='Population in 2017')
ax.set(ylabel='accident rate / (Population / 1e8)', xlabel='transit_log10')


plt.title('Relationship between Accident Rate and Percent Using Transit')
ax.legend()
plt.show()

# %% [markdown]
# ### __Part 2.2: Exploring relationships with "Average Severity"__
# <ins>Linear Regression of Average Severity and Percent Using Transit:</ins>
# <!-- TODO -->
#
# <ins>Linear Regression of Average Severity and Population in 2017:</ins>
# <!-- TODO -->

# %%
# create a subset of clean_df for column of interest for linear regression model
sub_col_sev_transit = ['avg_severity','Percent Using Transit']
sub_sev_rate = clean_df[sub_col_sev_transit]

# Apply a log-10 transformation for less skewed dataset

sub_sev_rate['transit_log10'] = np.log10(sub_sev_rate['Percent Using Transit']+0.1)
sub_sev_rate.head()
# Out:
#    avg_severity  Percent Using Transit  transit_log10
# 0      0.500000                  0.185      -0.545155
# 1      0.546612                  0.031      -0.882729
# 2      0.514423                  0.079      -0.747147
# 3      0.534253                  0.011      -0.954677
# 4      0.694248                  0.221      -0.493495

# %%
sub_sev_col_2 = ['avg_severity','Percent Using Transit','Population in 2017']
sub_sev_rate_2 = clean_df[sub_sev_col_2]

# Apply a log-10 transformation for less skewed dataset

sub_sev_rate_2['transit_log10'] = np.log10(sub_sev_rate_2['Percent Using Transit']+0.1)

# filter out the outliers from 'Population in 2017'
x = 2
mean = sub_sev_rate_2['Population in 2017'].mean()
std = sub_sev_rate_2['Population in 2017'].std()
filtered_pop  = sub_sev_rate_2[(sub_sev_rate_2['Population in 2017'] > (mean - x * std)) & (sub_sev_rate_2['Population in 2017']< (mean + x * std))]
filtered_pop

# Divide 'Population in 2017'by 1e8 to make it comparable in range of accident rate 
filtered_pop['pop_comp'] = filtered_pop['Population in 2017']/1e8
filtered_pop.head()
# Out:
#    avg_severity  Percent Using Transit  Population in 2017  transit_log10  \
# 0      0.500000                  0.185             79037.0      -0.545155
# 1      0.546612                  0.031            350476.0      -0.882729
# 2      0.514423                  0.079            111494.0      -0.747147
# 3      0.534253                  0.011            377940.0      -0.954677
# 4      0.694248                  0.221            122164.0      -0.493495
#
#    pop_comp
# 0  0.000790
# 1  0.003505
# 2  0.001115
# 3  0.003779
# 4  0.001222

# %%
fig, ax = plt.subplots(figsize=(14, 8))


sns.regplot(x='transit_log10', y='avg_severity', data=filtered_pop, fit_reg=True, ax=ax, label='Average Severity')
sns.regplot(x='transit_log10', y='pop_comp', data=filtered_pop, fit_reg=True, ax=ax, label='Population in 2017')
ax.set(ylabel='avg_severity / (Population / 1e8)', xlabel='transit_log10')


plt.title('Relationship between Average Severity Rates and Percent Using Transit')
ax.legend()
plt.show()

# %% [markdown]
# ### __Part 3: Finding evidence for correlation__
#
# <ins>OLS Model of Accident Rate and Percent Using Transit:</ins>
# 1. We observed that the p-value was 0.328, which is not less than 0.05. This makes it statistically insignificant. This suggests that there is not enough evidence to support our hypothesis.
# 2. We hypothesized that the higher use of public transportation lessens the number of accidents due to several factors.
# However, the results are too weak to prove that there is a correlation between these variables. Thus, we see that our null hypothesis is correct instead.

# %%
outcome,predictors= patsy.dmatrices('accident_rate ~ transit_log10',sub_accident_rate)
model = sm.OLS(outcome,predictors)
res_log = model.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          accident_rate   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9746
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):              0.328
# Time:                        11:55:59   Log-Likelihood:                 262.43
# No. Observations:                  58   AIC:                            -520.9
# Df Residuals:                      56   BIC:                            -516.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0063      0.002      2.881      0.006       0.002       0.011
# ...

# %% [markdown]
# <br>
# <ins>OLS Model of Accident Rate and Population in 2017:</ins>
# 1. We observe that the p-value is 0.981, which is not less than 0.05. This makes it statistically insignificant.
# We created this model to show the exclusion of "Percent Using Transit" before we combined "Population in 2017" and "Percent Using Transit."
# We will then try the inclusion of "Percent Using Transit" to explore if there is a confounding relationship.

# %%
outcome,predictors= patsy.dmatrices('accident_rate ~ pop_comp',filtered_pop)
model = sm.OLS(outcome,predictors)
res_log = model.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          accident_rate   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                 0.0005576
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):              0.981
# Time:                        11:55:59   Log-Likelihood:                 251.94
# No. Observations:                  56   AIC:                            -499.9
# Df Residuals:                      54   BIC:                            -495.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0042      0.001      7.340      0.000       0.003       0.005
# ...

# %% [markdown]
# <br>
#
# <ins>OLS Regression Results of Accident Rate and Percent Using Transit + Population in 2017:</ins>
# 1. We observed previously that the p-values for both "Percent Using Transit" and "Population in 2017" were well over 0.05 before the inclusion.
# After the inclusion, the p-values were still over 0.05, making them still insignificant.
# This implies that the coefficients are also statistically insignificant which means there is not strong enough evidence to suggest that there is an association with "Accident Rate."
# In other words, the inclusion and exclusion of "Percent Using Transit" does not change the association with "Accident Rate." Thus, there is also no confounding relationship.

# %%
potential_confound = 'accident_rate ~ transit_log10 + pop_comp'
outcome_2, predictors_2 = patsy.dmatrices(potential_confound, filtered_pop)

model_2 = sm.OLS(outcome_2, predictors_2)
res_2 = model_2.fit()
print(res_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          accident_rate   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                    0.4897
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):              0.616
# Time:                        11:55:59   Log-Likelihood:                 252.45
# No. Observations:                  56   AIC:                            -498.9
# Df Residuals:                      53   BIC:                            -492.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0065      0.002      2.709      0.009       0.002       0.011
# ...

# %% [markdown]
# ## Summary of Results

# %% [markdown]
# Our analysis shows that there is a lack of strong evidence to reject our null hypothesis. Specifically, we cannot conclude that the higher use of public transportation lessens the number of accidents, because the p-value for that regression was 0.328,  which is greater than 0.05, therefore statistically insignificant. A high p-value (>0.05) suggests the observed correlation could have occurred even if there is no true correlation in the data. There was no significant relationship between the Car Accident Rate and the Population in the California cities either (p-value was 0.981). Lastly, the p-values for both Transit Usage Rate (0.327) and Population (0.859) suggest that these variables are not statistically significant predictors of Car Accident Rate in our third regression model. We attempted to find correlations between these various factors, but we got results that supported random chance more than cause-and-effect relationships. This led us to conclude that Public Transport Rate does not correlate with Car Accident Rate, even when controlling for Population. And, considering our second scatterplot, which showed the lack of relationship between Car Accident Severity and Transit Usage Rate, there is no correlation to be found there, either.
#
#
# Ultimately, our interpretation of the results is that it’s impossible to control every factor involved with the occurrence of accidents; no single factor is in play when it comes to auto collision rates or severity.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# There should not be an issue with any biases from the source of collection as the dataset that we are exmaining the data from takes the data from multiple APIs which broadcast traffic data which is captured from various sources, including the US and state departments of transportation, law enforcement agencies, trafic cameras, and trafic sensors within road network. This should allow us to avoid any biases as there are many sources of information that went into this dataset which can validate each other. Additionally, as some of the data is taken in from traffic cameras and sensors, the data is inputted by a machine/algorithm which will remove human biases.
#
# However, there may be biases in which accidents were reported to the government as there may be racial/ethical biases when it came to reporting the accidents to the government.
# This may exclude certain demographics of people or target others, but as we are not focusing on race/demographics, it should not affect our data analysis as much. Additionally, since the data is vastly spread across the country and over the time frame of 2016 - 2013, the data should even out itself.
#
# One factor we may fail to fully consider is the location and its impact on each accident.
# For example, there may be weather conditions or other variables that we are unable to record that may be the main reason for the accident, yet we concluded a different reasoning with the information we analyzed.
# However, this should still be acceptable as the main goal of our hypothesis and research is to find out how certain factors consistently result in an accident.
# In other words, our focus is more on concluding if there will be an accident if a certain variable is present, rather than which variable is the most crucial out of all variables to lead to an accident.
#
#
# We will detect these specific biases before analysis by thoroughly discussing our research question before finding datasets and identifying any additional variables that would skew our data and affect our question.
# During data analysis, we will identify any points in the data that do not match up with the rest of the data and conduct additional research to identify whether those specific data points are abnormalities or whether they are biases that we did not take into account before.
# Then, we will explain the abnormalities/biases in our analysis and discuss how this affects our data.
# After we have already written our analysis of the data, we will proofread our conclusion for any other biases that may stand out and if they do occur, we will revise and address them again.
# Additionally, we may conduct a peer review (if allowed) with another group so we can have unbiased feedback.
#
# We will not be avoiding anyone's privacy when collecting data about the public transportation usage rates as the rates are generalized to the entire city and should not be exposing any indivdual person's privacy. To avoid violating anyone's privacy who was involved in the accident, we may remove/recode any information that can identify the individual(s) involved in the accident. This includes any distinguishing features about the vehicles involved in the accident.
#
# Our question will not bring up any ethical concerns as it does not dive into the demographics of any of the people involved in the study. It only takes into account the public rates of public transportation usage and car accident data. Our question will not have any ethical implications.

# %% [markdown]
# # Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.  A good time to refer back to your Background section and review how this work extended the previous stuff.
#
#
# # Team Contributions
#
# Speficy who did what.  This should be pretty granular, perhaps bullet points, no more than a few sentences per person.
#
# Elizaveta Beltyukova
# - wrote analysis for the first scatterplot
# - wrote background & prior work
# - helped with format
# - did part of the analysis/results section
